# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Used_Bikes.csv')

# %%
print(df)
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df['brand'].unique()
# Out:
# array(['TVS', 'Royal Enfield', 'Triumph', 'Yamaha', 'Honda', 'Hero',
#        'Bajaj', 'Suzuki', 'Benelli', 'KTM', 'Mahindra', 'Kawasaki',
#        'Ducati', 'Hyosung', 'Harley-Davidson', 'Jawa', 'BMW', 'Indian',
#        'Rajdoot', 'LML', 'Yezdi', 'MV', 'Ideal'], dtype=object)

# %%
df['brand'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                  TVS
# 1        Royal Enfield
# 2              Triumph
# 3                  TVS
# 4               Yamaha
#              ...
# 32643             Hero
# 32644              TVS
# 32645            Bajaj
# 32646             Hero
# 32647            Bajaj
# Name: brand, Length: 32648, dtype: object>

# %%
df['brand'] == 'Royal Enfield'
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 32643    False
# 32644    False
# 32645    False
# 32646    False
# 32647    False
# Name: brand, Length: 32648, dtype: bool

# %%
bullet = df[df['brand'] == 'Royal Enfield']

# %%
bullet.head()
# Out:
#                                    bike_name     price       city  kms_driven  \
# 1                Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 8          Royal Enfield Thunderbird X 350cc  145000.0  Bangalore      9190.0
# 9   Royal Enfield Classic Desert Storm 500cc   88000.0      Delhi     19000.0
# 23        Royal Enfield Classic Chrome 500cc  121700.0     Kalyan     24520.0
# 36               Royal Enfield Classic 350cc   98800.0      Kochi     39000.0
#
#            owner  age  power          brand
# 1    First Owner  4.0  350.0  Royal Enfield
# 8    First Owner  3.0  350.0  Royal Enfield
# 9   Second Owner  7.0  500.0  Royal Enfield
# 23   First Owner  5.0  500.0  Royal Enfield
# 36   First Owner  5.0  350.0  Royal Enfield

# %%
bullet.shape
# Out:
# (4178, 8)

# %%
# brand = royal enfield
# age == less than 2 year
#owner == first owner

bullete = (df['city'] == 'jaipur') & (df['age']<=2) & (df['owner'] == 'First Owner')

# %%
bullete
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32643    False
# 32644    False
# 32645    False
# 32646    False
# 32647    False
# Length: 32648, dtype: bool

# %%
bullete.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
bullete.shape
# Out:
# (32648,)

# %%
bullete['city'].nunique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 bullete['city'].nunique()
#
# File c:\Python311\Lib\site-packages\pandas\core\series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File c:\Python311\Lib\site-packages\pandas\core\series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# -> 1237 loc = self.index.get_loc(label)
#    1239 if is_integer(loc):
#    1240     return self._values[loc]
#
# ...

# %%
bullete['city'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 bullete['city'].value_counts()
#
# File c:\Python311\Lib\site-packages\pandas\core\series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File c:\Python311\Lib\site-packages\pandas\core\series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# -> 1237 loc = self.index.get_loc(label)
#    1239 if is_integer(loc):
#    1240     return self._values[loc]
#
# ...

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df['brand'].unique()
# Out:
# array(['TVS', 'Royal Enfield', 'Triumph', 'Yamaha', 'Honda', 'Hero',
#        'Bajaj', 'Suzuki', 'Benelli', 'KTM', 'Mahindra', 'Kawasaki',
#        'Ducati', 'Hyosung', 'Harley-Davidson', 'Jawa', 'BMW', 'Indian',
#        'Rajdoot', 'LML', 'Yezdi', 'MV', 'Ideal'], dtype=object)

# %%
bike = df[(df['brand'] == 'KTM') | (df['brand'] == 'Jawa')]
bike
# Out:
#               bike_name     price        city  kms_driven         owner  age  \
# 33         KTM RC 390cc  180000.0        Pune     17700.0   First Owner  4.0
# 35       KTM Duke 200cc   70000.0      Nashik    100000.0  Second Owner  8.0
# 39     KTM RC 200cc ABS  179000.0   Bangalore      3400.0   First Owner  2.0
# 65       KTM Duke 200cc   94700.0    Baripara     32700.0   First Owner  4.0
# 83       KTM Duke 250cc  130000.0  Gandhidham     17500.0  Second Owner  4.0
# ...                 ...       ...         ...         ...           ...  ...
# 32541      KTM RC 390cc  196700.0      Mumbai     13216.0   First Owner  4.0
# 32560      KTM RC 390cc  196700.0      Mumbai     13216.0   First Owner  4.0
# 32579      KTM RC 390cc  196700.0      Mumbai     13216.0   First Owner  4.0
# 32598      KTM RC 390cc  196700.0      Mumbai     13216.0   First Owner  4.0
# 32636      KTM RC 390cc  196700.0      Mumbai     13216.0   First Owner  4.0
#
#        power brand
# 33     390.0   KTM
# ...

# %%
bike['brand'].value_counts()
# Out:
# brand
# KTM     1077
# Jawa      10
# Name: count, dtype: int64

# %%
if 'Jaipur' in bike['city'].unique():
    print('present')
else :  
    print('not present')
# Out:
# present

# %%
bike
# Out:
#               bike_name     price        city  kms_driven         owner  age  \
# 33         KTM RC 390cc  180000.0        Pune     17700.0   First Owner  4.0
# 35       KTM Duke 200cc   70000.0      Nashik    100000.0  Second Owner  8.0
# 39     KTM RC 200cc ABS  179000.0   Bangalore      3400.0   First Owner  2.0
# 65       KTM Duke 200cc   94700.0    Baripara     32700.0   First Owner  4.0
# 83       KTM Duke 250cc  130000.0  Gandhidham     17500.0  Second Owner  4.0
# ...                 ...       ...         ...         ...           ...  ...
# 32541      KTM RC 390cc  196700.0      Mumbai     13216.0   First Owner  4.0
# 32560      KTM RC 390cc  196700.0      Mumbai     13216.0   First Owner  4.0
# 32579      KTM RC 390cc  196700.0      Mumbai     13216.0   First Owner  4.0
# 32598      KTM RC 390cc  196700.0      Mumbai     13216.0   First Owner  4.0
# 32636      KTM RC 390cc  196700.0      Mumbai     13216.0   First Owner  4.0
#
#        power brand
# 33     390.0   KTM
# ...

# %%
bike['city'].value_counts()
# Out:
# city
# Mumbai         703
# Delhi           65
# Bangalore       55
# Pune            36
# Hyderabad       27
#               ...
# Challakere       1
# Hooghly          1
# Bhubaneswar      1
# Raigarh(mh)      1
# Berhampore       1
# Name: count, Length: 91, dtype: int64

# %%
bike[bike['city'] == 'Jaipur']
# Out:
#            bike_name     price    city  kms_driven        owner  age  power  \
# 888     KTM RC 390cc  147000.0  Jaipur     15000.0  First Owner  6.0  390.0
# 4945  KTM Duke 390cc  200000.0  Jaipur     11700.0  First Owner  4.0  390.0
# 4948    KTM RC 390cc  175000.0  Jaipur     10880.0  First Owner  4.0  390.0
# 6073    KTM RC 200cc  190000.0  Jaipur      7902.0  First Owner  2.0  200.0
# 6159  KTM Duke 250cc  135000.0  Jaipur     12507.0  First Owner  4.0  250.0
# 6552    KTM RC 200cc  190000.0  Jaipur      7902.0  First Owner  2.0  200.0
# 6734    KTM RC 200cc  128000.0  Jaipur     15000.0  First Owner  4.0  200.0
# 7561  KTM Duke 250cc  150000.0  Jaipur     12500.0  First Owner  4.0  250.0
#
#      brand
# 888    KTM
# 4945   KTM
# 4948   KTM
# 6073   KTM
# 6159   KTM
# 6552   KTM
# 6734   KTM
# 7561   KTM

# %%
# population dat ==> df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  object
#  1   price       32648 non-null  float64
#  2   city        32648 non-null  object
#  3   kms_driven  32648 non-null  float64
#  4   owner       32648 non-null  object
#  5   age         32648 non-null  float64
#  6   power       32648 non-null  float64
#  7   brand       32648 non-null  object
# dtypes: float64(4), object(4)
# memory usage: 2.0+ MB

# %%
df.shape    # actual ==> 32648
# Out:
# (32648, 8)

# %%
df.duplicated().sum()   # duplicated ==> 25324
# Out:
# np.int64(25324)

# %%
df.drop_duplicates()(inplace = True)        # not duplication ==> 7324
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 df.drop_duplicates()(inplace = True)        # not duplication ==> 7324
#
# TypeError: 'DataFrame' object is not callable

# %%
df.shape
# Out:
# (32648, 8)

# %%
bullete = df[df['brand'] == 'yamah']
bullet
# Out:
#                                       bike_name     price  \
# 1                   Royal Enfield Classic 350cc  119900.0
# 8             Royal Enfield Thunderbird X 350cc  145000.0
# 9      Royal Enfield Classic Desert Storm 500cc   88000.0
# 23           Royal Enfield Classic Chrome 500cc  121700.0
# 36                  Royal Enfield Classic 350cc   98800.0
# ...                                         ...       ...
# 32601               Royal Enfield Classic 350cc   95500.0
# 32614        Royal Enfield Bullet Electra 350cc  105000.0
# 32633               Royal Enfield Classic 350cc   87000.0
# 32634           Royal Enfield Thunderbird 350cc   70000.0
# 32639               Royal Enfield Classic 350cc   95500.0
#
#                       city  kms_driven         owner   age  power  \
# 1                    Delhi     11000.0   First Owner   4.0  350.0
# 8                Bangalore      9190.0   First Owner   3.0  350.0
# 9                    Delhi     19000.0  Second Owner   7.0  500.0
# ...

# %%
bullet.shot_values(by='price').head(10)         #ascending order
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8812\4177452063.py in ?()
# ----> 1 bullet.shot_values(by='price').head(10)
#
# c:\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'shot_values'

# %%
bullet.shape
# Out:
# (4178, 8)

# %%
bullet.shot_values(by='price',ascending = True).head(10)        #descending order
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8812\481635075.py in ?()
# ----> 1 bullet.shot_values(by='price',ascending = True)        #discending order
#
# c:\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'shot_values'

# %%
df.brand.value_counts()
# Out:
# brand
# Bajaj              11213
# Hero                6368
# Royal Enfield       4178
# Yamaha              3916
# Honda               2108
# Suzuki              1464
# TVS                 1247
# KTM                 1077
# Harley-Davidson      737
# Kawasaki              79
# Hyosung               64
# Benelli               56
# Mahindra              55
# Triumph               26
# Ducati                22
# BMW                   16
# Jawa                  10
# MV                     4
# Indian                 3
# Ideal                  2
# Rajdoot                1
# Yezdi                  1
# LML                    1
# Name: count, dtype: int64

# %%
yamaha1 = df[df['brand'] == 'Yamaha']
yamaha1
# Out:
#                                   bike_name     price         city  \
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0    Bangalore
# 5                          Yamaha FZs 150cc   53499.0        Delhi
# 10                 Yamaha YZF-R15 2.0 150cc   72000.0    Bangalore
# 11                        Yamaha FZ25 250cc   95000.0    Bangalore
# 24                    Yamaha FZ V 2.0 150cc   45000.0        Delhi
# ...                                     ...       ...          ...
# 32610                       Yamaha FZ 150cc   45000.0      Chennai
# 32612              Yamaha YZF-R15 2.0 150cc   55000.0     Rupnagar
# 32622                    Yamaha Fazer 150cc   25000.0        Delhi
# 32631                    Yamaha SZ-RR 150cc   20000.0  Kanchipuram
# 32638                 Yamaha Fazer 25 250cc  123000.0       Kadapa
#
#        kms_driven        owner   age  power   brand
# 4         10000.0  First Owner   3.0  150.0  Yamaha
# 5         25000.0  First Owner   6.0  150.0  Yamaha
# ...

# %%
# yamaha.to_csv('yamaha.csv',index=False)   # export csv file

# %%
yamaha1[['bike_name','price','age','kms_driven']]

#buike_name  , price  , age  , km_driven
# Out:
#                                   bike_name     price   age  kms_driven
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0   3.0     10000.0
# 5                          Yamaha FZs 150cc   53499.0   6.0     25000.0
# 10                 Yamaha YZF-R15 2.0 150cc   72000.0   7.0     20000.0
# 11                        Yamaha FZ25 250cc   95000.0   4.0      9665.0
# 24                    Yamaha FZ V 2.0 150cc   45000.0   6.0     23000.0
# ...                                     ...       ...   ...         ...
# 32610                       Yamaha FZ 150cc   45000.0   6.0     18742.0
# 32612              Yamaha YZF-R15 2.0 150cc   55000.0   9.0     27000.0
# 32622                    Yamaha Fazer 150cc   25000.0  12.0     65000.0
# 32631                    Yamaha SZ-RR 150cc   20000.0  10.0     52000.0
# 32638                 Yamaha Fazer 25 250cc  123000.0   4.0     14500.0
#
# [3916 rows x 4 columns]

# %%
yamaha1.drop(['owner','city','power'],axis = 'columns',inplace=True)

# remove coumns parmanent
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8812\147013368.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yamaha1.drop(['owner','city','power'],axis = 'columns',inplace=True)

# %%
yamaha1
# Out:
#                                   bike_name     price  kms_driven   age  \
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0     10000.0   3.0
# 5                          Yamaha FZs 150cc   53499.0     25000.0   6.0
# 10                 Yamaha YZF-R15 2.0 150cc   72000.0     20000.0   7.0
# 11                        Yamaha FZ25 250cc   95000.0      9665.0   4.0
# 24                    Yamaha FZ V 2.0 150cc   45000.0     23000.0   6.0
# ...                                     ...       ...         ...   ...
# 32610                       Yamaha FZ 150cc   45000.0     18742.0   6.0
# 32612              Yamaha YZF-R15 2.0 150cc   55000.0     27000.0   9.0
# 32622                    Yamaha Fazer 150cc   25000.0     65000.0  12.0
# 32631                    Yamaha SZ-RR 150cc   20000.0     52000.0  10.0
# 32638                 Yamaha Fazer 25 250cc  123000.0     14500.0   4.0
#
#         brand
# 4      Yamaha
# 5      Yamaha
# 10     Yamaha
# 11     Yamaha
# 24     Yamaha
# ...

# %%
yamaha1.to_csv('yamaha1.csv',index=False)

# %%
yamaha1.shot_values(by='kms_driven',ascending = True).head(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8812\2029362855.py in ?()
# ----> 1 yamaha.shot_values(by='kms_driven',ascending = True).head(10)
#
# c:\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'shot_values'

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Used_Bikes.csv')
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
data = {'A':[2,5,np.nan,8,np.nan,9],
        'B':[np.nan,45,np.nan,89,63,np.nan],
        'C':[np.nan,74,np.nan,np.nan,85,4],
        'D':[10,20,30,40,50,60]}
data
# Out:
# {'A': [2, 5, nan, 8, nan, 9],
#  'B': [nan, 45, nan, 89, 63, nan],
#  'C': [nan, 74, nan, nan, 85, 4],
#  'D': [10, 20, 30, 40, 50, 60]}

# %%
df2 = pd.DataFrame(data)
df2
# Out:
#      A     B     C   D
# 0  2.0   NaN   NaN  10
# 1  5.0  45.0  74.0  20
# 2  NaN   NaN   NaN  30
# 3  8.0  89.0   NaN  40
# 4  NaN  63.0  85.0  50
# 5  9.0   NaN   4.0  60

# %%
df2.dropna()            # by defalut remove all thos rows that containg mising values
# Out:
#      A     B     C   D
# 1  5.0  45.0  74.0  20

# %%
df2.dropna(axis='columns')          ## by defalut remove all thos columns that containg mising values
# Out:
#     D
# 0  10
# 1  20
# 2  30
# 3  40
# 4  50
# 5  60

# %%
df2.isnull().sum()          # sum null values
# Out:
# A    2
# B    3
# C    3
# D    0
# dtype: int64

# %%
print('Total mising values in your df :',df2.isnull().sum().sum())
# Out:
# Total mising values in your df : 8

# %%
df2.shape[0]
# Out:
# 6

# %%
df2.isnull().sum()/df2.shape[0]*100
# Out:
# A    33.333333
# B    50.000000
# C    50.000000
# D     0.000000
# dtype: float64

# %%
## filling tha reords

df2.fillna(500)             # inplace=True
# Out:
#        A      B      C   D
# 0    2.0  500.0  500.0  10
# 1    5.0   45.0   74.0  20
# 2  500.0  500.0  500.0  30
# 3    8.0   89.0  500.0  40
# 4  500.0   63.0   85.0  50
# 5    9.0  500.0    4.0  60

# %%
# A = 500
# B = 600
# C = 700

df2['A'].fillna(500)
# Out:
# 0      2.0
# 1      5.0
# 2    500.0
# 3      8.0
# 4    500.0
# 5      9.0
# Name: A, dtype: float64

# %%
df2['B'].fillna(600)
# Out:
# 0    600.0
# 1     45.0
# 2    600.0
# 3     89.0
# 4     63.0
# 5    600.0
# Name: B, dtype: float64

# %%
df2['C'].fillna(700)
# Out:
# 0    700.0
# 1     74.0
# 2    700.0
# 3    700.0
# 4     85.0
# 5      4.0
# Name: C, dtype: float64

# %%
df2["A"].mean()             # mean values of colunm A
# Out:
# np.float64(6.0)

# %%
df2["A"].median()
# Out:
# np.float64(6.5)

# %%
df2["A"].mode()
# Out:
# 0    2.0
# 1    5.0
# 2    8.0
# 3    9.0
# Name: A, dtype: float64

# %%
df2['A'].fillna(df2["A"].mean())
# Out:
# 0    2.0
# 1    5.0
# 2    6.0
# 3    8.0
# 4    6.0
# 5    9.0
# Name: A, dtype: float64

# %%
df2['A'].fillna(df2["A"].median())
# Out:
# 0    2.0
# 1    5.0
# 2    6.5
# 3    8.0
# 4    6.5
# 5    9.0
# Name: A, dtype: float64

# %%
df2['A'].fillna(df2["A"].mode())
# Out:
# 0    2.0
# 1    5.0
# 2    8.0
# 3    8.0
# 4    NaN
# 5    9.0
# Name: A, dtype: float64

# %%
### Groupby

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df['price']
# Out:
# 0         35000.0
# 1        119900.0
# 2        600000.0
# 3         65000.0
# 4         80000.0
#            ...
# 32643     39000.0
# 32644     30000.0
# 32645     60000.0
# 32646     15600.0
# 32647     22000.0
# Name: price, Length: 32648, dtype: float64

# %%
df['price'].min()
# Out:
# np.float64(4400.0)

# %%
df['price'].max()
# Out:
# np.float64(1900000.0)

# %%
df['price'].mean()
# Out:
# np.float64(68295.41763660868)

# %%
df[df['brand'] == 'TVS']['price'].min()
# Out:
# np.float64(5800.0)

# %%
brand_group = df.groupby('brand')
brand_group

# %%
brand_group.get_group('TVS')
# Out:
#                                 bike_name    price       city  kms_driven  \
# 0      TVS Star City Plus Dual Tone 110cc  35000.0  Ahmedabad     17654.0
# 3                    TVS Apache RTR 180cc  65000.0  Bangalore     16329.0
# 52                   TVS Apache RTR 160cc  60000.0     Mumbai     30000.0
# 114            TVS Apache RTR 160 4V Disc  69900.0      Delhi      8700.0
# 130                TVS Phoenix Disc 125cc  21500.0    Barasat     10500.0
# ...                                   ...      ...        ...         ...
# 32549                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32568                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32587                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32606                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32644                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
#
#              owner  age  power brand
# 0      First Owner  3.0  110.0   TVS
# ...

# %%
brand_group.get_group('TVS').min()
# Out:
# bike_name     TVS Apache 150cc
# price                   5800.0
# city                    Adalaj
# kms_driven               100.0
# owner              First Owner
# age                        1.0
# power                    100.0
# brand                      TVS
# dtype: object

# %%
brand_group[['price']].min()
# Out:
#                     price
# brand
# BMW              255000.0
# Bajaj              6400.0
# Benelli          110700.0
# Ducati           380000.0
# Harley-Davidson  250000.0
# Hero               5000.0
# Honda             10000.0
# Hyosung          120000.0
# Ideal            100000.0
# Indian           700000.0
# Jawa             146000.0
# KTM               55000.0
# Kawasaki         110000.0
# LML                4400.0
# MV               950000.0
# Mahindra          17800.0
# Rajdoot           75000.0
# Royal Enfield     33500.0
# Suzuki             8000.0
# TVS                5800.0
# Triumph          500000.0
# Yamaha             9400.0
# Yezdi             68000.0

# %%
brand_group[['price']].max()
# Out:
#                      price
# brand
# BMW              1800000.0
# Bajaj             195000.0
# Benelli           785000.0
# Ducati           1500000.0
# Harley-Davidson  1100000.0
# Hero              104000.0
# Honda             800000.0
# Hyosung           493500.0
# Ideal             100000.0
# Indian           1900000.0
# Jawa              223000.0
# KTM               860000.0
# Kawasaki         1100000.0
# LML                 4400.0
# MV               1500000.0
# Mahindra          175000.0
# Rajdoot            75000.0
# Royal Enfield     285000.0
# Suzuki           1260000.0
# TVS               224000.0
# Triumph          1300000.0
# Yamaha           1550000.0
# Yezdi              68000.0

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
brand_group['price'].agg(min_price = 'min', max_price = 'max', avg_price = 'mean')
# Out:
#                  min_price  max_price     avg_price
# brand
# BMW               255000.0  1800000.0  5.987500e+05
# Bajaj               6400.0   195000.0  4.833127e+04
# Benelli           110700.0   785000.0  2.942000e+05
# Ducati            380000.0  1500000.0  9.355455e+05
# Harley-Davidson   250000.0  1100000.0  4.529988e+05
# Hero                5000.0   104000.0  2.382945e+04
# Honda              10000.0   800000.0  5.923047e+04
# Hyosung           120000.0   493500.0  2.491678e+05
# Ideal             100000.0   100000.0  1.000000e+05
# Indian            700000.0  1900000.0  1.100000e+06
# Jawa              146000.0   223000.0  1.855000e+05
# KTM                55000.0   860000.0  1.746697e+05
# Kawasaki          110000.0  1100000.0  4.116246e+05
# LML                 4400.0     4400.0  4.400000e+03
# MV                950000.0  1500000.0  1.325000e+06
# Mahindra           17800.0   175000.0  7.250709e+04
# Rajdoot            75000.0    75000.0  7.500000e+04
# ...

# %%
brand_group['brand'].agg(min_kms = 'min', max_kms = 'max', avg_kms = 'mean')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File c:\Python311\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Python311\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
#
# ...

# %%
df['owner'].value_counts()
# Out:
# owner
# First Owner             29964
# Second Owner             2564
# Third Owner               108
# Fourth Owner Or More       12
# Name: count, dtype: int64

# %%
owner_group = df.groupby('owner')
owner_group

# %%
owner_group.get_group('owner')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 owner_group.get_group('owner')
#
# File c:\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1114, in BaseGroupBy.get_group(self, name, obj)
#    1112 inds = self._get_index(name)
#    1113 if not len(inds):
# -> 1114     raise KeyError(name)
#    1116 if obj is None:
#    1117     indexer = inds if self.axis == 0 else (slice(None), inds)
#
# KeyError: 'owner'

# %%
df.dtypes
# Out:
# bike_name      object
# price         float64
# city           object
# kms_driven    float64
# owner          object
# age           float64
# power         float64
# brand          object
# dtype: object

# %%
cat_col = df.select_dtypes(include='O')
cat_col.head()
# Out:
#                               bike_name       city        owner          brand
# 0    TVS Star City Plus Dual Tone 110cc  Ahmedabad  First Owner            TVS
# 1           Royal Enfield Classic 350cc      Delhi  First Owner  Royal Enfield
# 2                  Triumph Daytona 675R      Delhi  First Owner        Triumph
# 3                  TVS Apache RTR 180cc  Bangalore  First Owner            TVS
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore  First Owner         Yamaha

# %%
num_col = df.select_dtypes(exclude='O')
num_col.head()
# Out:
#       price  kms_driven  age  power
# 0   35000.0     17654.0  3.0  110.0
# 1  119900.0     11000.0  4.0  350.0
# 2  600000.0       110.0  8.0  675.0
# 3   65000.0     16329.0  4.0  180.0
# 4   80000.0     10000.0  3.0  150.0

# %%
df3 = pd.concat([cat_col,num_col],axis='columns')
df3.head()
# Out:
#                               bike_name       city        owner  \
# 0    TVS Star City Plus Dual Tone 110cc  Ahmedabad  First Owner
# 1           Royal Enfield Classic 350cc      Delhi  First Owner
# 2                  Triumph Daytona 675R      Delhi  First Owner
# 3                  TVS Apache RTR 180cc  Bangalore  First Owner
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore  First Owner
#
#            brand     price  kms_driven  age  power
# 0            TVS   35000.0     17654.0  3.0  110.0
# 1  Royal Enfield  119900.0     11000.0  4.0  350.0
# 2        Triumph  600000.0       110.0  8.0  675.0
# 3            TVS   65000.0     16329.0  4.0  180.0
# 4         Yamaha   80000.0     10000.0  3.0  150.0

# %%
pd.merge
# Out:
# <function pandas.core.reshape.merge.merge(left: 'DataFrame | Series', right: 'DataFrame | Series', how: 'MergeHow' = 'inner', on: 'IndexLabel | AnyArrayLike | None' = None, left_on: 'IndexLabel | AnyArrayLike | None' = None, right_on: 'IndexLabel | AnyArrayLike | None' = None, left_index: 'bool' = False, right_index: 'bool' = False, sort: 'bool' = False, suffixes: 'Suffixes' = ('_x', '_y'), copy: 'bool | None' = None, indicator: 'str | bool' = False, validate: 'str | None' = None) -> 'DataFrame'>
